# %%
import Conf_Calculator as CC
import pandas as pd

# %%
orderData = CC.sales_analysis_gen_matcher()
advantages_disadvantages = CC.AdvantageDisadvantageCal()

# %%
pd.DataFrame(orderData['data']), advantages_disadvantages[0], l_key
# Out:
#      Month  OrdSeq  code  unit_Price_QTY CPU_level_tag cache_limit_tag  \
# 0        1       5    34       5539.8081      Platinum          single
# 1        2      14    34       5419.3590      Platinum          single
# 2        3      35    34       5337.2475      Platinum          single
# 3        1       6    26       5277.4788      Platinum          single
# 4        4      17    26       5084.5275      Platinum          single
# ..     ...     ...   ...             ...           ...             ...
# 130      3      11   137       5101.7850        Silver        multiple
# 131      3      27    89       5001.1650          Gold        multiple
# 132      3      34    89       5001.1650          Gold        multiple
# 133      4      13    93       5296.0050          Gold        multiple
# 134      5      20    93       5296.0050          Gold        multiple
#
#     vSAN_level_tag  N_years_service_tag
# 0       Enterprise                    3
# ...
