# %%
import sqlite3  as sql3
import pandas as pd

# %%
users = {"User": ['test', 'another'], "Password":["test", "1234"]}
datF  = pd.DataFrame(users)

# %%
datF
# Out:
#       User Password
# 0     test     test
# 1  another     1234

# %%
savedAnalisys = {"User": ['test', 'another'], "storedAnalisys":["", ""]}
savedAnalisysDF  = pd.DataFrame(savedAnalisys)

# %%
savedAnalisysDF
# Out:
#       User storedAnalisys
# 0     test
# 1  another

# %%
conn = sql3.connect('accounts.db')

# %%
datF.to_sql('users', conn, if_exists='replace', index=False)

# %%
savedAnalisysDF.to_sql('analysis', conn, if_exists='replace', index=False)

# %%
conn = sql3.connect('accounts.db')
c = conn.cursor()
t = ('test',)
c.execute('SELECT * FROM users WHERE User=?', t)
print(c.fetchone())
conn.close()
# Out:
# ('test', 'test')

# %%
conn = sql3.connect('.\\accounts.db')
c = conn.cursor()
values = ( 'ciccio', 'test')
sql = ''' UPDATE analysis SET storedAnalisys = ? where User= ?'''
c.execute(sql, values)
conn.commit()
conn.close()
