# %% [markdown]
# ## WDIS: Service for OCpR: Areas of Opportunities

# %% [markdown]
# ### Import Statement

# %%
import pandas as pd
import numpy as np
import copy
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Utility Functions

# %%
def filter_out_descriptions_and_non_tags(df):
    sku_desc_filter_out = lambda x: 'sku_desc' not in x
    sku_qty_tag = lambda x: not( ('sku' not in x) and ('qty' not in x) and ('tag' not in x))
    cols_non_desc =  list(filter(sku_desc_filter_out, df.columns.to_list()))
    
    cols_non_desc =  list(filter(sku_qty_tag, cols_non_desc))
    
    
    return copy.copy(df[cols_non_desc])

def filter_out_tags(df):
    sku_w_tags = lambda x: 'tag' not in x
    cols_non_desc =  list(filter(sku_w_tags, df.columns.to_list()))
    return copy.copy(df[cols_non_desc])

def keep_tags(df):
    sku_w_tags = lambda x: 'tag' in x
    cols_tags =  list(filter(sku_w_tags, df.columns.to_list()))
    return copy.copy(df[cols_tags])


def column_renamer(df, sheet_name):
    df.columns = [ sheet_name+'_' + x if (('sku' in x) or ('qty' in x)) else x for x in  df.columns.to_list()]
    return df

def dataframes_splitter(path_to_the_file = r'.\uploads\VxRail_E560N.xls', list_for_splits=['Street_Prices', 'List_Prices']):
    OCpR_dfs, Prices_dfs = [], []
    
    excel_ = pd.ExcelFile(path_to_the_file)

    worksheets_names = excel_.sheet_names
    for ws_ in worksheets_names:

        if (ws_ in list_for_splits) or ('Prices_' in ws_) :
            some_details = pd.read_excel(excel_, sheet_name=ws_)
            some_details.title = ws_
            Prices_dfs.append(some_details )
        else:
            df_comb = filter_out_descriptions_and_non_tags(pd.read_excel(excel_, sheet_name=ws_))
            
            OCpR_dfs.append(column_renamer(df_comb, ws_))
    
    return OCpR_dfs, Prices_dfs


def common_tags(df_l, df_r):
    left_ = df_l.columns.to_list()
    rigth_ = df_r.columns.to_list()
    return list(set(left_).intersection(rigth_))

def loop_thru_dataframes(df_list, howhow='inner'):
    ocpr_df = pd.DataFrame()
    counter =  1
    for d_ in df_list:
        if counter == 1:
            ocpr_df = d_
            counter += 1
        else:
            cmmn_tags_list = common_tags(ocpr_df, d_)
            if len(cmmn_tags_list) == 0:
                ocpr_df['comKey'] = 1
                d_['comKey'] = 1
                ocpr_df = pd.merge( ocpr_df, d_, on ='comKey', how=howhow)
                ocpr_df = ocpr_df.drop(columns=['comKey'])
            else:
                ocpr_df = pd.merge( ocpr_df, d_, on=cmmn_tags_list ,how=howhow)    
    return ocpr_df

def order_columns(df):
    sku_and_qty = lambda x : ('sku' in x) or ('qty' in x)
    tag = lambda x : ('tag' in x) 
    cols_ = df.columns.to_list()
    return  pd.concat( [ df[list(filter(sku_and_qty, cols_))], df[list(filter(tag, cols_))] ], axis=1)


def OCpR_stacker(df):
    
    OCpR_stackable = filter_out_tags(df)
    OCpR_conf_tags = keep_tags(df)
    list_to_add_as_code =[x+1 for x in  OCpR_conf_tags.index.to_list().copy()]     
    OCpR_conf_tags['code'] = list_to_add_as_code
    
    rows_to_stack = [] 
    for row in OCpR_stackable.iterrows():
        conf_number = row[0]
        example = row
        col_ = 1
        elements_to_stuck = []
        for elem_ in row[1]: 

            if col_%2 == 0:
                                
                elements_to_stuck.append(elem_)
                elements_to_stuck.append(conf_number+1)
                rows_to_stack.append(elements_to_stuck)
                elements_to_stuck = []
            else:
                elements_to_stuck.append(elem_)

            col_ +=1
    return pd.DataFrame(rows_to_stack, columns=['SKU', 'qty','code']), OCpR_conf_tags

# %% [markdown]
# ### OCpR Process

# %%
def AnalysisDF(path_to_the_file__ ):

    dfs, details_dfs = dataframes_splitter(path_to_the_file = path_to_the_file__)
    OCpR = loop_thru_dataframes(dfs)
    OCpR_staked, OCpR_tags = OCpR_stacker(OCpR)
    details_dfs.insert(0,OCpR_staked)
    df_ca = loop_thru_dataframes(details_dfs, howhow='left')

    #ListPrices
    df_ca['q_by_Lp'] = df_ca['List_Price'] * df_ca['qty']
    df_ca = df_ca.fillna(0.0)
    Conf_List_prices = df_ca[['code','q_by_Lp']].groupby('code').sum()
    Conf_List_prices['code'] = Conf_List_prices.index
    Conf_List_prices.index = Conf_List_prices.index.rename('index')

    #StreetPrices
    df_ca['q_by_Sp'] = df_ca['Street_Price'] * df_ca['qty']
    df_ca = df_ca.fillna(0.0)
    Conf_Street_prices = df_ca[['code','q_by_Sp']].groupby('code').sum()
    Conf_Street_prices['code'] = Conf_List_prices.index
    Conf_Street_prices.index = Conf_Street_prices.index.rename('index')

    final_df = pd.merge(OCpR_tags,Conf_List_prices, on='code', how='inner')

    final_df = pd.merge(final_df,Conf_Street_prices, on='code', how='inner')
    
    return final_df

# %% [markdown]
# ### Comparison Process

# %%
Competitor0 = AnalysisDF(r'C:/Users/zuzan/Desktop/MyCompany.xls')
Competitor1 = AnalysisDF(r'C:/Users/zuzan/Desktop/Competitor.xls')

Comp0 = pd.concat([Competitor0[list(filter(lambda x: 'tag' in x,  Competitor0.columns))], Competitor0[['q_by_Lp','q_by_Sp']] ] , axis=1)
Comp1 = pd.concat([Competitor1[list(filter(lambda x: 'tag' in x,  Competitor1.columns))], Competitor1[['q_by_Lp','q_by_Sp']] ] , axis=1)

Comp0_grouped = Comp0.groupby(list(filter(lambda x: 'tag' in x,  Comp0.columns))).mean().reset_index() 
Comp1_grouped = Comp1.groupby(list(filter(lambda x: 'tag' in x,  Comp1.columns))).mean().reset_index() 


cmmn_tags_list = list(filter(lambda x: not(('q_by_Lp' in x) or ('q_by_Sp' in x)) , common_tags(Comp0_grouped, Comp1_grouped)))

ocpr_df = pd.merge(Comp0_grouped, Comp1_grouped, on=cmmn_tags_list ,how='inner', suffixes=('_0', '_1'))

# %% [markdown]
# ### AD (advantages and Disadvantages)

# %%
MyCompany_LP_Advantage = ocpr_df[ocpr_df['q_by_Lp_0'] < ocpr_df['q_by_Lp_1']].to_json(orient="records")
MyCompany_SP_Advantage = ocpr_df[ocpr_df['q_by_Sp_0'] < ocpr_df['q_by_Sp_1']].to_json(orient="records")
Competitor_SP_Advantage = ocpr_df[ocpr_df['q_by_Sp_0'] > ocpr_df['q_by_Sp_1']].to_json(orient="records")
Competitor_LP_Advantage = ocpr_df[ocpr_df['q_by_Lp_0'] > ocpr_df['q_by_Lp_1']].to_json(orient="records")

competition_Vantages = "{" + f""" "MyCompany_LP_Advantage" : {MyCompany_LP_Advantage}
, "MyCompany_SP_Advantage" : {MyCompany_SP_Advantage} 
, "Competitor_SP_Advantage" : {Competitor_SP_Advantage} 
, "Competitor_LP_Advantage" : {Competitor_LP_Advantage} """ + "}"

# %% [markdown]
# ### OT ( opportunities and threats)

# %%
import json

# %%
criteria = (Competitor0['CPU_level_tag'] =='Gold') \
        & (Competitor0['cache_limit_tag'] =='single')\
        & (Competitor0['vSAN_level_tag'] =='ELA')

# %%
TO_dict = {'Threats' : [Competitor1, Comp0_grouped], 'Opportunities':[Competitor0, Comp1_grouped]}
Threats_and_Opportunities = {}
for key_ in TO_dict.keys():
    
    _comparison_items =  TO_dict[key_]
    comp_0, comp_1 = _comparison_items[0], _comparison_items[1]

    competition = pd.merge(
                    comp_0,
                    comp_1,
                   on= list(filter(lambda x: 'tag' in x,  common_tags(Competitor0,Comp1_grouped))),
                   how='inner', 
                   suffixes=('_AdvSrch', '_CompAdv'))  

    criteria_advantage_LP = competition['q_by_Lp_AdvSrch'] < competition['q_by_Lp_CompAdv']
    criteria_advantage_SP = competition['q_by_Sp_AdvSrch'] < competition['q_by_Sp_CompAdv']
    
    Advantage_LP = (json.loads(competition[criteria_advantage_LP].to_json(orient="records")))
    Advantage_SP = (json.loads(competition[criteria_advantage_SP].to_json(orient="records")))

    Threats_and_Opportunities[key_] = [{'ListPrices':Advantage_LP} 
                                       ,{'StreetPrices':Advantage_SP}]

# %%
Threats_and_Opportunities
# Out:
# {'Threats': [{'ListPrices': [{'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 1,
#      'q_by_Lp_AdvSrch': 11088.0,
#      'q_by_Sp_AdvSrch': 5544.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 2,
#      'q_by_Lp_AdvSrch': 11080.0,
#      'q_by_Sp_AdvSrch': 5540.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 3,
#      'q_by_Lp_AdvSrch': 11088.0,
#      'q_by_Sp_AdvSrch': 5544.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 4,
#      'q_by_Lp_AdvSrch': 11080.0,
#      'q_by_Sp_AdvSrch': 5540.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 5,
#      'q_by_Lp_AdvSrch': 11408.0,
#      'q_by_Sp_AdvSrch': 5704.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 6,
#      'q_by_Lp_AdvSrch': 11400.0,
#      'q_by_Sp_AdvSrch': 5700.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 7,
#      'q_by_Lp_AdvSrch': 11408.0,
#      'q_by_Sp_AdvSrch': 5704.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 8,
#      'q_by_Lp_AdvSrch': 11400.0,
#      'q_by_Sp_AdvSrch': 5700.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 9,
#      'q_by_Lp_AdvSrch': 11648.0,
#      'q_by_Sp_AdvSrch': 5824.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 10,
#      'q_by_Lp_AdvSrch': 11640.0,
#      'q_by_Sp_AdvSrch': 5820.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 11,
#      'q_by_Lp_AdvSrch': 11648.0,
#      'q_by_Sp_AdvSrch': 5824.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 12,
#      'q_by_Lp_AdvSrch': 11640.0,
#      'q_by_Sp_AdvSrch': 5820.0,
#      'q_by_Lp_CompAdv': 13142.5,
#      'q_by_Sp_CompAdv': 5234.25},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 13,
#      'q_by_Lp_AdvSrch': 11111.0,
#      'q_by_Sp_AdvSrch': 5555.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 14,
#      'q_by_Lp_AdvSrch': 11103.0,
#      'q_by_Sp_AdvSrch': 5551.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 15,
#      'q_by_Lp_AdvSrch': 11111.0,
#      'q_by_Sp_AdvSrch': 5555.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 16,
#      'q_by_Lp_AdvSrch': 11103.0,
#      'q_by_Sp_AdvSrch': 5551.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 17,
#      'q_by_Lp_AdvSrch': 11431.0,
#      'q_by_Sp_AdvSrch': 5715.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 18,
#      'q_by_Lp_AdvSrch': 11423.0,
#      'q_by_Sp_AdvSrch': 5711.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 19,
#      'q_by_Lp_AdvSrch': 11431.0,
#      'q_by_Sp_AdvSrch': 5715.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 20,
#      'q_by_Lp_AdvSrch': 11423.0,
#      'q_by_Sp_AdvSrch': 5711.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 21,
#      'q_by_Lp_AdvSrch': 11671.0,
#      'q_by_Sp_AdvSrch': 5835.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 22,
#      'q_by_Lp_AdvSrch': 11663.0,
#      'q_by_Sp_AdvSrch': 5831.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 23,
#      'q_by_Lp_AdvSrch': 11671.0,
#      'q_by_Sp_AdvSrch': 5835.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 24,
#      'q_by_Lp_AdvSrch': 11663.0,
#      'q_by_Sp_AdvSrch': 5831.5,
#      'q_by_Lp_CompAdv': 13163.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 25,
#      'q_by_Lp_AdvSrch': 11148.0,
#      'q_by_Sp_AdvSrch': 5574.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 26,
#      'q_by_Lp_AdvSrch': 11140.0,
#      'q_by_Sp_AdvSrch': 5570.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 27,
#      'q_by_Lp_AdvSrch': 11148.0,
#      'q_by_Sp_AdvSrch': 5574.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 28,
#      'q_by_Lp_AdvSrch': 11140.0,
#      'q_by_Sp_AdvSrch': 5570.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 29,
#      'q_by_Lp_AdvSrch': 11468.0,
#      'q_by_Sp_AdvSrch': 5734.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 30,
#      'q_by_Lp_AdvSrch': 11460.0,
#      'q_by_Sp_AdvSrch': 5730.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 31,
#      'q_by_Lp_AdvSrch': 11468.0,
#      'q_by_Sp_AdvSrch': 5734.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 32,
#      'q_by_Lp_AdvSrch': 11460.0,
#      'q_by_Sp_AdvSrch': 5730.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 33,
#      'q_by_Lp_AdvSrch': 11708.0,
#      'q_by_Sp_AdvSrch': 5854.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 34,
#      'q_by_Lp_AdvSrch': 11700.0,
#      'q_by_Sp_AdvSrch': 5850.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 35,
#      'q_by_Lp_AdvSrch': 11708.0,
#      'q_by_Sp_AdvSrch': 5854.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 36,
#      'q_by_Lp_AdvSrch': 11700.0,
#      'q_by_Sp_AdvSrch': 5850.0,
#      'q_by_Lp_CompAdv': 13220.5,
#      'q_by_Sp_CompAdv': 5286.45},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 37,
#      'q_by_Lp_AdvSrch': 11171.0,
#      'q_by_Sp_AdvSrch': 5585.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 38,
#      'q_by_Lp_AdvSrch': 11163.0,
#      'q_by_Sp_AdvSrch': 5581.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 39,
#      'q_by_Lp_AdvSrch': 11171.0,
#      'q_by_Sp_AdvSrch': 5585.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 40,
#      'q_by_Lp_AdvSrch': 11163.0,
#      'q_by_Sp_AdvSrch': 5581.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 41,
#      'q_by_Lp_AdvSrch': 11491.0,
#      'q_by_Sp_AdvSrch': 5745.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 42,
#      'q_by_Lp_AdvSrch': 11483.0,
#      'q_by_Sp_AdvSrch': 5741.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 43,
#      'q_by_Lp_AdvSrch': 11491.0,
#      'q_by_Sp_AdvSrch': 5745.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 44,
#      'q_by_Lp_AdvSrch': 11483.0,
#      'q_by_Sp_AdvSrch': 5741.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 45,
#      'q_by_Lp_AdvSrch': 11731.0,
#      'q_by_Sp_AdvSrch': 5865.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 46,
#      'q_by_Lp_AdvSrch': 11723.0,
#      'q_by_Sp_AdvSrch': 5861.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 47,
#      'q_by_Lp_AdvSrch': 11731.0,
#      'q_by_Sp_AdvSrch': 5865.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 48,
#      'q_by_Lp_AdvSrch': 11723.0,
#      'q_by_Sp_AdvSrch': 5861.5,
#      'q_by_Lp_CompAdv': 13241.5,
#      'q_by_Sp_CompAdv': 5305.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 49,
#      'q_by_Lp_AdvSrch': 11514.0,
#      'q_by_Sp_AdvSrch': 5757.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 50,
#      'q_by_Lp_AdvSrch': 11506.0,
#      'q_by_Sp_AdvSrch': 5753.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 51,
#      'q_by_Lp_AdvSrch': 11514.0,
#      'q_by_Sp_AdvSrch': 5757.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 52,
#      'q_by_Lp_AdvSrch': 11506.0,
#      'q_by_Sp_AdvSrch': 5753.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 53,
#      'q_by_Lp_AdvSrch': 11834.0,
#      'q_by_Sp_AdvSrch': 5917.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 54,
#      'q_by_Lp_AdvSrch': 11826.0,
#      'q_by_Sp_AdvSrch': 5913.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 55,
#      'q_by_Lp_AdvSrch': 11834.0,
#      'q_by_Sp_AdvSrch': 5917.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 56,
#      'q_by_Lp_AdvSrch': 11826.0,
#      'q_by_Sp_AdvSrch': 5913.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 57,
#      'q_by_Lp_AdvSrch': 12074.0,
#      'q_by_Sp_AdvSrch': 6037.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 58,
#      'q_by_Lp_AdvSrch': 12066.0,
#      'q_by_Sp_AdvSrch': 6033.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 59,
#      'q_by_Lp_AdvSrch': 12074.0,
#      'q_by_Sp_AdvSrch': 6037.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 60,
#      'q_by_Lp_AdvSrch': 12066.0,
#      'q_by_Sp_AdvSrch': 6033.0,
#      'q_by_Lp_CompAdv': 13474.5,
#      'q_by_Sp_CompAdv': 5337.45},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 61,
#      'q_by_Lp_AdvSrch': 11537.0,
#      'q_by_Sp_AdvSrch': 5768.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 62,
#      'q_by_Lp_AdvSrch': 11529.0,
#      'q_by_Sp_AdvSrch': 5764.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 63,
#      'q_by_Lp_AdvSrch': 11537.0,
#      'q_by_Sp_AdvSrch': 5768.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 64,
#      'q_by_Lp_AdvSrch': 11529.0,
#      'q_by_Sp_AdvSrch': 5764.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 65,
#      'q_by_Lp_AdvSrch': 11857.0,
#      'q_by_Sp_AdvSrch': 5928.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 66,
#      'q_by_Lp_AdvSrch': 11849.0,
#      'q_by_Sp_AdvSrch': 5924.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 67,
#      'q_by_Lp_AdvSrch': 11857.0,
#      'q_by_Sp_AdvSrch': 5928.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 68,
#      'q_by_Lp_AdvSrch': 11849.0,
#      'q_by_Sp_AdvSrch': 5924.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 69,
#      'q_by_Lp_AdvSrch': 12097.0,
#      'q_by_Sp_AdvSrch': 6048.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 70,
#      'q_by_Lp_AdvSrch': 12089.0,
#      'q_by_Sp_AdvSrch': 6044.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 71,
#      'q_by_Lp_AdvSrch': 12097.0,
#      'q_by_Sp_AdvSrch': 6048.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 72,
#      'q_by_Lp_AdvSrch': 12089.0,
#      'q_by_Sp_AdvSrch': 6044.5,
#      'q_by_Lp_CompAdv': 13495.5,
#      'q_by_Sp_CompAdv': 5356.35},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 73,
#      'q_by_Lp_AdvSrch': 11150.0,
#      'q_by_Sp_AdvSrch': 5575.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 74,
#      'q_by_Lp_AdvSrch': 11142.0,
#      'q_by_Sp_AdvSrch': 5571.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 75,
#      'q_by_Lp_AdvSrch': 11150.0,
#      'q_by_Sp_AdvSrch': 5575.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 76,
#      'q_by_Lp_AdvSrch': 11142.0,
#      'q_by_Sp_AdvSrch': 5571.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 77,
#      'q_by_Lp_AdvSrch': 11470.0,
#      'q_by_Sp_AdvSrch': 5735.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 78,
#      'q_by_Lp_AdvSrch': 11462.0,
#      'q_by_Sp_AdvSrch': 5731.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 79,
#      'q_by_Lp_AdvSrch': 11470.0,
#      'q_by_Sp_AdvSrch': 5735.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 80,
#      'q_by_Lp_AdvSrch': 11462.0,
#      'q_by_Sp_AdvSrch': 5731.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 81,
#      'q_by_Lp_AdvSrch': 11710.0,
#      'q_by_Sp_AdvSrch': 5855.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 82,
#      'q_by_Lp_AdvSrch': 11702.0,
#      'q_by_Sp_AdvSrch': 5851.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 83,
#      'q_by_Lp_AdvSrch': 11710.0,
#      'q_by_Sp_AdvSrch': 5855.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 84,
#      'q_by_Lp_AdvSrch': 11702.0,
#      'q_by_Sp_AdvSrch': 5851.0,
#      'q_by_Lp_CompAdv': 13133.5,
#      'q_by_Sp_CompAdv': 5226.15},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 85,
#      'q_by_Lp_AdvSrch': 11173.0,
#      'q_by_Sp_AdvSrch': 5586.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 86,
#      'q_by_Lp_AdvSrch': 11165.0,
#      'q_by_Sp_AdvSrch': 5582.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 87,
#      'q_by_Lp_AdvSrch': 11173.0,
#      'q_by_Sp_AdvSrch': 5586.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 88,
#      'q_by_Lp_AdvSrch': 11165.0,
#      'q_by_Sp_AdvSrch': 5582.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 89,
#      'q_by_Lp_AdvSrch': 11493.0,
#      'q_by_Sp_AdvSrch': 5746.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 90,
#      'q_by_Lp_AdvSrch': 11485.0,
#      'q_by_Sp_AdvSrch': 5742.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 91,
#      'q_by_Lp_AdvSrch': 11493.0,
#      'q_by_Sp_AdvSrch': 5746.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 92,
#      'q_by_Lp_AdvSrch': 11485.0,
#      'q_by_Sp_AdvSrch': 5742.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 93,
#      'q_by_Lp_AdvSrch': 11733.0,
#      'q_by_Sp_AdvSrch': 5866.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 94,
#      'q_by_Lp_AdvSrch': 11725.0,
#      'q_by_Sp_AdvSrch': 5862.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 95,
#      'q_by_Lp_AdvSrch': 11733.0,
#      'q_by_Sp_AdvSrch': 5866.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 96,
#      'q_by_Lp_AdvSrch': 11725.0,
#      'q_by_Sp_AdvSrch': 5862.5,
#      'q_by_Lp_CompAdv': 13154.5,
#      'q_by_Sp_CompAdv': 5245.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 97,
#      'q_by_Lp_AdvSrch': 11106.0,
#      'q_by_Sp_AdvSrch': 5553.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 98,
#      'q_by_Lp_AdvSrch': 11098.0,
#      'q_by_Sp_AdvSrch': 5549.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 99,
#      'q_by_Lp_AdvSrch': 11106.0,
#      'q_by_Sp_AdvSrch': 5553.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 100,
#      'q_by_Lp_AdvSrch': 11098.0,
#      'q_by_Sp_AdvSrch': 5549.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 101,
#      'q_by_Lp_AdvSrch': 11426.0,
#      'q_by_Sp_AdvSrch': 5713.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 102,
#      'q_by_Lp_AdvSrch': 11418.0,
#      'q_by_Sp_AdvSrch': 5709.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 103,
#      'q_by_Lp_AdvSrch': 11426.0,
#      'q_by_Sp_AdvSrch': 5713.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 104,
#      'q_by_Lp_AdvSrch': 11418.0,
#      'q_by_Sp_AdvSrch': 5709.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 105,
#      'q_by_Lp_AdvSrch': 11666.0,
#      'q_by_Sp_AdvSrch': 5833.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 106,
#      'q_by_Lp_AdvSrch': 11658.0,
#      'q_by_Sp_AdvSrch': 5829.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 107,
#      'q_by_Lp_AdvSrch': 11666.0,
#      'q_by_Sp_AdvSrch': 5833.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 108,
#      'q_by_Lp_AdvSrch': 11658.0,
#      'q_by_Sp_AdvSrch': 5829.0,
#      'q_by_Lp_CompAdv': 13183.5,
#      'q_by_Sp_CompAdv': 5253.15},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 109,
#      'q_by_Lp_AdvSrch': 11129.0,
#      'q_by_Sp_AdvSrch': 5564.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 110,
#      'q_by_Lp_AdvSrch': 11121.0,
#      'q_by_Sp_AdvSrch': 5560.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 111,
#      'q_by_Lp_AdvSrch': 11129.0,
#      'q_by_Sp_AdvSrch': 5564.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 112,
#      'q_by_Lp_AdvSrch': 11121.0,
#      'q_by_Sp_AdvSrch': 5560.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 113,
#      'q_by_Lp_AdvSrch': 11449.0,
#      'q_by_Sp_AdvSrch': 5724.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 114,
#      'q_by_Lp_AdvSrch': 11441.0,
#      'q_by_Sp_AdvSrch': 5720.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 115,
#      'q_by_Lp_AdvSrch': 11449.0,
#      'q_by_Sp_AdvSrch': 5724.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 116,
#      'q_by_Lp_AdvSrch': 11441.0,
#      'q_by_Sp_AdvSrch': 5720.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 117,
#      'q_by_Lp_AdvSrch': 11689.0,
#      'q_by_Sp_AdvSrch': 5844.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 118,
#      'q_by_Lp_AdvSrch': 11681.0,
#      'q_by_Sp_AdvSrch': 5840.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 119,
#      'q_by_Lp_AdvSrch': 11689.0,
#      'q_by_Sp_AdvSrch': 5844.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 120,
#      'q_by_Lp_AdvSrch': 11681.0,
#      'q_by_Sp_AdvSrch': 5840.5,
#      'q_by_Lp_CompAdv': 13204.5,
#      'q_by_Sp_CompAdv': 5272.05},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 121,
#      'q_by_Lp_AdvSrch': 11518.0,
#      'q_by_Sp_AdvSrch': 5759.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 122,
#      'q_by_Lp_AdvSrch': 11510.0,
#      'q_by_Sp_AdvSrch': 5755.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 123,
#      'q_by_Lp_AdvSrch': 11518.0,
#      'q_by_Sp_AdvSrch': 5759.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 124,
#      'q_by_Lp_AdvSrch': 11510.0,
#      'q_by_Sp_AdvSrch': 5755.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 125,
#      'q_by_Lp_AdvSrch': 11838.0,
#      'q_by_Sp_AdvSrch': 5919.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 126,
#      'q_by_Lp_AdvSrch': 11830.0,
#      'q_by_Sp_AdvSrch': 5915.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 127,
#      'q_by_Lp_AdvSrch': 11838.0,
#      'q_by_Sp_AdvSrch': 5919.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 128,
#      'q_by_Lp_AdvSrch': 11830.0,
#      'q_by_Sp_AdvSrch': 5915.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 129,
#      'q_by_Lp_AdvSrch': 12078.0,
#      'q_by_Sp_AdvSrch': 6039.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 130,
#      'q_by_Lp_AdvSrch': 12070.0,
#      'q_by_Sp_AdvSrch': 6035.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 131,
#      'q_by_Lp_AdvSrch': 12078.0,
#      'q_by_Sp_AdvSrch': 6039.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 132,
#      'q_by_Lp_AdvSrch': 12070.0,
#      'q_by_Sp_AdvSrch': 6035.0,
#      'q_by_Lp_CompAdv': 13465.5,
#      'q_by_Sp_CompAdv': 5329.35},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 133,
#      'q_by_Lp_AdvSrch': 11541.0,
#      'q_by_Sp_AdvSrch': 5770.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 134,
#      'q_by_Lp_AdvSrch': 11533.0,
#      'q_by_Sp_AdvSrch': 5766.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 135,
#      'q_by_Lp_AdvSrch': 11541.0,
#      'q_by_Sp_AdvSrch': 5770.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 136,
#      'q_by_Lp_AdvSrch': 11533.0,
#      'q_by_Sp_AdvSrch': 5766.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 137,
#      'q_by_Lp_AdvSrch': 11861.0,
#      'q_by_Sp_AdvSrch': 5930.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 138,
#      'q_by_Lp_AdvSrch': 11853.0,
#      'q_by_Sp_AdvSrch': 5926.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 139,
#      'q_by_Lp_AdvSrch': 11861.0,
#      'q_by_Sp_AdvSrch': 5930.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 140,
#      'q_by_Lp_AdvSrch': 11853.0,
#      'q_by_Sp_AdvSrch': 5926.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 141,
#      'q_by_Lp_AdvSrch': 12101.0,
#      'q_by_Sp_AdvSrch': 6050.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 142,
#      'q_by_Lp_AdvSrch': 12093.0,
#      'q_by_Sp_AdvSrch': 6046.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 143,
#      'q_by_Lp_AdvSrch': 12101.0,
#      'q_by_Sp_AdvSrch': 6050.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 144,
#      'q_by_Lp_AdvSrch': 12093.0,
#      'q_by_Sp_AdvSrch': 6046.5,
#      'q_by_Lp_CompAdv': 13486.5,
#      'q_by_Sp_CompAdv': 5348.25}]},
#   {'StreetPrices': []}],
#  'Opportunities': [{'ListPrices': []},
#   {'StreetPrices': [{'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 1,
#      'q_by_Lp_AdvSrch': 12903.0,
#      'q_by_Sp_AdvSrch': 5162.7,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 2,
#      'q_by_Lp_AdvSrch': 12902.0,
#      'q_by_Sp_AdvSrch': 5161.8,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 3,
#      'q_by_Lp_AdvSrch': 12903.0,
#      'q_by_Sp_AdvSrch': 5162.7,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 4,
#      'q_by_Lp_AdvSrch': 12902.0,
#      'q_by_Sp_AdvSrch': 5161.8,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 5,
#      'q_by_Lp_AdvSrch': 12759.0,
#      'q_by_Sp_AdvSrch': 5119.5,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 6,
#      'q_by_Lp_AdvSrch': 12758.0,
#      'q_by_Sp_AdvSrch': 5118.6,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 7,
#      'q_by_Lp_AdvSrch': 12759.0,
#      'q_by_Sp_AdvSrch': 5119.5,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 8,
#      'q_by_Lp_AdvSrch': 12758.0,
#      'q_by_Sp_AdvSrch': 5118.6,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 9,
#      'q_by_Lp_AdvSrch': 13767.0,
#      'q_by_Sp_AdvSrch': 5421.9,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 10,
#      'q_by_Lp_AdvSrch': 13766.0,
#      'q_by_Sp_AdvSrch': 5421.0,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 11,
#      'q_by_Lp_AdvSrch': 13767.0,
#      'q_by_Sp_AdvSrch': 5421.9,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 12,
#      'q_by_Lp_AdvSrch': 13766.0,
#      'q_by_Sp_AdvSrch': 5421.0,
#      'q_by_Lp_CompAdv': 11377.3333333333,
#      'q_by_Sp_CompAdv': 5688.6666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 13,
#      'q_by_Lp_AdvSrch': 12924.0,
#      'q_by_Sp_AdvSrch': 5181.6,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 14,
#      'q_by_Lp_AdvSrch': 12923.0,
#      'q_by_Sp_AdvSrch': 5180.7,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 15,
#      'q_by_Lp_AdvSrch': 12924.0,
#      'q_by_Sp_AdvSrch': 5181.6,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 16,
#      'q_by_Lp_AdvSrch': 12923.0,
#      'q_by_Sp_AdvSrch': 5180.7,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 17,
#      'q_by_Lp_AdvSrch': 12780.0,
#      'q_by_Sp_AdvSrch': 5138.4,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 18,
#      'q_by_Lp_AdvSrch': 12779.0,
#      'q_by_Sp_AdvSrch': 5137.5,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 19,
#      'q_by_Lp_AdvSrch': 12780.0,
#      'q_by_Sp_AdvSrch': 5138.4,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 20,
#      'q_by_Lp_AdvSrch': 12779.0,
#      'q_by_Sp_AdvSrch': 5137.5,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 21,
#      'q_by_Lp_AdvSrch': 13788.0,
#      'q_by_Sp_AdvSrch': 5440.8,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 22,
#      'q_by_Lp_AdvSrch': 13787.0,
#      'q_by_Sp_AdvSrch': 5439.9,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 23,
#      'q_by_Lp_AdvSrch': 13788.0,
#      'q_by_Sp_AdvSrch': 5440.8,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 24,
#      'q_by_Lp_AdvSrch': 13787.0,
#      'q_by_Sp_AdvSrch': 5439.9,
#      'q_by_Lp_CompAdv': 11400.3333333333,
#      'q_by_Sp_CompAdv': 5700.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'Enterprise',
#      'N_years_service_tag': 3,
#      'code': 25,
#      'q_by_Lp_AdvSrch': 12981.0,
#      'q_by_Sp_AdvSrch': 5214.9,
#      'q_by_Lp_CompAdv': 11437.3333333333,
# ...
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 91,
#      'q_by_Lp_AdvSrch': 12771.0,
#      'q_by_Sp_AdvSrch': 5130.3,
#      'q_by_Lp_CompAdv': 11462.3333333333,
#      'q_by_Sp_CompAdv': 5731.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 92,
#      'q_by_Lp_AdvSrch': 12770.0,
#      'q_by_Sp_AdvSrch': 5129.4,
#      'q_by_Lp_CompAdv': 11462.3333333333,
#      'q_by_Sp_CompAdv': 5731.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 93,
#      'q_by_Lp_AdvSrch': 13779.0,
#      'q_by_Sp_AdvSrch': 5432.7,
#      'q_by_Lp_CompAdv': 11462.3333333333,
#      'q_by_Sp_CompAdv': 5731.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 94,
#      'q_by_Lp_AdvSrch': 13778.0,
#      'q_by_Sp_AdvSrch': 5431.8,
#      'q_by_Lp_CompAdv': 11462.3333333333,
#      'q_by_Sp_CompAdv': 5731.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 95,
#      'q_by_Lp_AdvSrch': 13779.0,
#      'q_by_Sp_AdvSrch': 5432.7,
#      'q_by_Lp_CompAdv': 11462.3333333333,
#      'q_by_Sp_CompAdv': 5731.1666666667},
#     {'CPU_level_tag': 'Gold',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 96,
#      'q_by_Lp_AdvSrch': 13778.0,
#      'q_by_Sp_AdvSrch': 5431.8,
#      'q_by_Lp_CompAdv': 11462.3333333333,
#      'q_by_Sp_CompAdv': 5731.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 97,
#      'q_by_Lp_AdvSrch': 12944.0,
#      'q_by_Sp_AdvSrch': 5181.6,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 98,
#      'q_by_Lp_AdvSrch': 12943.0,
#      'q_by_Sp_AdvSrch': 5180.7,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 99,
#      'q_by_Lp_AdvSrch': 12944.0,
#      'q_by_Sp_AdvSrch': 5181.6,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 100,
#      'q_by_Lp_AdvSrch': 12943.0,
#      'q_by_Sp_AdvSrch': 5180.7,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 101,
#      'q_by_Lp_AdvSrch': 12800.0,
#      'q_by_Sp_AdvSrch': 5138.4,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 102,
#      'q_by_Lp_AdvSrch': 12799.0,
#      'q_by_Sp_AdvSrch': 5137.5,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 103,
#      'q_by_Lp_AdvSrch': 12800.0,
#      'q_by_Sp_AdvSrch': 5138.4,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 104,
#      'q_by_Lp_AdvSrch': 12799.0,
#      'q_by_Sp_AdvSrch': 5137.5,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 105,
#      'q_by_Lp_AdvSrch': 13808.0,
#      'q_by_Sp_AdvSrch': 5440.8,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 106,
#      'q_by_Lp_AdvSrch': 13807.0,
#      'q_by_Sp_AdvSrch': 5439.9,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 107,
#      'q_by_Lp_AdvSrch': 13808.0,
#      'q_by_Sp_AdvSrch': 5440.8,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 108,
#      'q_by_Lp_AdvSrch': 13807.0,
#      'q_by_Sp_AdvSrch': 5439.9,
#      'q_by_Lp_CompAdv': 11395.3333333333,
#      'q_by_Sp_CompAdv': 5697.6666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 109,
#      'q_by_Lp_AdvSrch': 12965.0,
#      'q_by_Sp_AdvSrch': 5200.5,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 110,
#      'q_by_Lp_AdvSrch': 12964.0,
#      'q_by_Sp_AdvSrch': 5199.6,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 111,
#      'q_by_Lp_AdvSrch': 12965.0,
#      'q_by_Sp_AdvSrch': 5200.5,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 112,
#      'q_by_Lp_AdvSrch': 12964.0,
#      'q_by_Sp_AdvSrch': 5199.6,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 113,
#      'q_by_Lp_AdvSrch': 12821.0,
#      'q_by_Sp_AdvSrch': 5157.3,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 114,
#      'q_by_Lp_AdvSrch': 12820.0,
#      'q_by_Sp_AdvSrch': 5156.4,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 115,
#      'q_by_Lp_AdvSrch': 12821.0,
#      'q_by_Sp_AdvSrch': 5157.3,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 116,
#      'q_by_Lp_AdvSrch': 12820.0,
#      'q_by_Sp_AdvSrch': 5156.4,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 117,
#      'q_by_Lp_AdvSrch': 13829.0,
#      'q_by_Sp_AdvSrch': 5459.7,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 118,
#      'q_by_Lp_AdvSrch': 13828.0,
#      'q_by_Sp_AdvSrch': 5458.8,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 119,
#      'q_by_Lp_AdvSrch': 13829.0,
#      'q_by_Sp_AdvSrch': 5459.7,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Platinum',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 120,
#      'q_by_Lp_AdvSrch': 13828.0,
#      'q_by_Sp_AdvSrch': 5458.8,
#      'q_by_Lp_CompAdv': 11418.3333333333,
#      'q_by_Sp_CompAdv': 5709.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 121,
#      'q_by_Lp_AdvSrch': 13226.0,
#      'q_by_Sp_AdvSrch': 5257.8,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 122,
#      'q_by_Lp_AdvSrch': 13225.0,
#      'q_by_Sp_AdvSrch': 5256.9,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 123,
#      'q_by_Lp_AdvSrch': 13226.0,
#      'q_by_Sp_AdvSrch': 5257.8,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 124,
#      'q_by_Lp_AdvSrch': 13225.0,
#      'q_by_Sp_AdvSrch': 5256.9,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 125,
#      'q_by_Lp_AdvSrch': 13082.0,
#      'q_by_Sp_AdvSrch': 5214.6,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 126,
#      'q_by_Lp_AdvSrch': 13081.0,
#      'q_by_Sp_AdvSrch': 5213.7,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 127,
#      'q_by_Lp_AdvSrch': 13082.0,
#      'q_by_Sp_AdvSrch': 5214.6,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 128,
#      'q_by_Lp_AdvSrch': 13081.0,
#      'q_by_Sp_AdvSrch': 5213.7,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 129,
#      'q_by_Lp_AdvSrch': 14090.0,
#      'q_by_Sp_AdvSrch': 5517.0,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 130,
#      'q_by_Lp_AdvSrch': 14089.0,
#      'q_by_Sp_AdvSrch': 5516.1,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 131,
#      'q_by_Lp_AdvSrch': 14090.0,
#      'q_by_Sp_AdvSrch': 5517.0,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'single',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 132,
#      'q_by_Lp_AdvSrch': 14089.0,
#      'q_by_Sp_AdvSrch': 5516.1,
#      'q_by_Lp_CompAdv': 11807.3333333333,
#      'q_by_Sp_CompAdv': 5903.6666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 133,
#      'q_by_Lp_AdvSrch': 13247.0,
#      'q_by_Sp_AdvSrch': 5276.7,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 134,
#      'q_by_Lp_AdvSrch': 13246.0,
#      'q_by_Sp_AdvSrch': 5275.8,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 135,
#      'q_by_Lp_AdvSrch': 13247.0,
#      'q_by_Sp_AdvSrch': 5276.7,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 136,
#      'q_by_Lp_AdvSrch': 13246.0,
#      'q_by_Sp_AdvSrch': 5275.8,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 137,
#      'q_by_Lp_AdvSrch': 13103.0,
#      'q_by_Sp_AdvSrch': 5233.5,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 138,
#      'q_by_Lp_AdvSrch': 13102.0,
#      'q_by_Sp_AdvSrch': 5232.6,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 139,
#      'q_by_Lp_AdvSrch': 13103.0,
#      'q_by_Sp_AdvSrch': 5233.5,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 140,
#      'q_by_Lp_AdvSrch': 13102.0,
#      'q_by_Sp_AdvSrch': 5232.6,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 141,
#      'q_by_Lp_AdvSrch': 14111.0,
#      'q_by_Sp_AdvSrch': 5535.9,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 142,
#      'q_by_Lp_AdvSrch': 14110.0,
#      'q_by_Sp_AdvSrch': 5535.0,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 143,
#      'q_by_Lp_AdvSrch': 14111.0,
#      'q_by_Sp_AdvSrch': 5535.9,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667},
#     {'CPU_level_tag': 'Silver',
#      'cache_limit_tag': 'multiple',
#      'vSAN_level_tag': 'ELA',
#      'N_years_service_tag': 3,
#      'code': 144,
#      'q_by_Lp_AdvSrch': 14110.0,
#      'q_by_Sp_AdvSrch': 5535.0,
#      'q_by_Lp_CompAdv': 11830.3333333333,
#      'q_by_Sp_CompAdv': 5915.1666666667}]}]}
